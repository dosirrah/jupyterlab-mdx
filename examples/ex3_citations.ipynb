# %% [markdown]
# In Section #goo we explain it.

# %% [markdown]
# # @goo Goolia

# %% [markdown]
# Smith^smith2020 derives the equations for low-energy time machines powered by the warm gaseous emanations of bloviating charlatans.
#
# Lamport ^lamport1994 provides great info.

# %% [markdown]
# <!--
# Automatically added by jupyterlab-mdx because you cited something (^lamport1994)
# but hadn’t yet created a bibliography. When you run this cell it will
# generate your reference list. If you’d like a different .bib file,
# just change the “src:” path below.
# -->
#
# ::: bibliography
# src: ex.bib
# :::
