# %% [markdown]
# # Notebook Title

# %% [markdown]
# ## Introduction
#
# Figure @fig:architecture shows the system.

# %% [markdown]
# ## Methods
#
# $$
# \int_{x=0}^t x^2 dx   @eq:integral
# $$

# %% [markdown]
# See #fig:architecture in #introduction and #eq:integral in #methods.
