# %% [markdown]
# Opening text.

# %%
print('no citation here')

# %% [markdown]
# See ^lamport1994 and ^knuth1984.

# %%
ref = '^turing1936'

# %% [markdown]
# Plain markdown.

# %% [markdown]
# See ^turing1936.

# %% [markdown]
# ::: bibliography
# src: multiple_entries.bib
# :::
