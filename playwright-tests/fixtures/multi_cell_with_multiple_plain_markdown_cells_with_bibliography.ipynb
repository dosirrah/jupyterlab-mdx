# %% [markdown]
# Intro text only.

# %% [markdown]
# See ^lamport1994.

# %% [markdown]
# More discussion with no citations.

# %% [markdown]
# See ^knuth1984 and ^turing1936.

# %% [markdown]
# Conclusion without citations.

# %% [markdown]
# ::: bibliography
# src: multiple_entries.bib
# :::
