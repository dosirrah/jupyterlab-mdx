# %% [markdown]
# ## Overview

# %% [markdown]
# Figure @fig:system shows the full system.

# %% [markdown]
# $$
# a^2 + b^2 = c^2   @eq:pythagoras
# $$

# %% [markdown]
# In #overview, see #fig:system and #eq:pythagoras.
